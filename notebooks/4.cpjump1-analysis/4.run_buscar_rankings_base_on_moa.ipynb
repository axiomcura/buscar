# %%
import sys
import pathlib
import json
import logging
from pprint import pprint

import polars as pl
from tqdm import tqdm

sys.path.append("../../")
from utils.signatures import get_signatures
from utils.identify_hits import identify_compound_hit
from utils.metrics import measure_phenotypic_activity
from utils.io_utils import load_profiles, load_configs
from utils.data_utils import shuffle_feature_profiles, split_meta_and_features

# %% [markdown]
# Setting input and output paths

# %%
# setting data directory
data_dir = pathlib.Path("../0.download-data/data/sc-profiles/").resolve(strict=True)
results_module_dir = pathlib.Path("./results").resolve(strict=True)

# setting cpjump1_dataset
cpjump1_profiles_path = (
    data_dir / "cpjump1/cpjump1_compound_concat_profiles.parquet"
).resolve(strict=True)

# get experimental dataset
cpjump1_experimental_metadata_path = (
    data_dir / "cpjump1/CPJUMP1-experimental-metadata.csv"
).resolve(strict=True)

# get shared feature space
shared_feature_space = (
    data_dir / "cpjump1/feature_selected_sc_qc_features.json"
).resolve(strict=True)

# moa config
cpjump1_compounds_moa = (data_dir / "cpjump1/cpjump1_compound_moa.tsv").resolve(
    strict=True
)

# set cluster labels dirctory
u2os_cluster_labels_path = (
    results_module_dir / "clusters/cpjump1_u2os_clusters.parquet"
).resolve(strict=True)

# create MoA analysis output directory
moa_analysis_output_dir = (results_module_dir / "moa_analysis").resolve()
moa_analysis_output_dir.mkdir(parents=True, exist_ok=True)

# %%
# loading shared features
shared_features = load_configs(shared_feature_space)["shared-features"]

# loading experimental and moa metadata
cpjump1_moa_df = pl.read_csv(cpjump1_compounds_moa, separator="\t")
cpjump1_experimental_data = pl.read_csv(cpjump1_experimental_metadata_path)

# Cluster labels
cluster_labels_df = pl.read_parquet(u2os_cluster_labels_path)

# load profiles
cpjump1_df = load_profiles(cpjump1_profiles_path)
cpjump1_meta, cpjump1_feats = split_meta_and_features(cpjump1_df)

# replace treatments where the MoA is 'null' to 'unknown'
cpjump1_moa_df = cpjump1_moa_df.with_columns(
    pl.when(pl.col("Metadata_moa").is_null())
    .then(pl.lit("unknown"))
    .otherwise(pl.col("Metadata_moa"))
    .alias("Metadata_moa")
)

# displaying dataframe information
print(f"Dataframe shape: {cpjump1_df.shape}")
print(
    "Number of unique treatments",
    cpjump1_df["Metadata_pert_iname"].n_unique(),
)

cpjump1_df.head()
# Out:
# Dataframe shape: (6505782, 323)
# Number of unique treatments 303
# shape: (5, 323)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ … ┆ Nuclei_Co ┆ Cytoplasm ┆ Cytoplasm ┆ Nuclei_R │
# │ cell_id   ┆ broad_sam ┆ solvent   ┆ ImageNumb ┆   ┆ rrelation ┆ _Texture_ ┆ _RadialDi ┆ adialDis │
# │ ---       ┆ ple       ┆ ---       ┆ er        ┆   ┆ _Correlat ┆ Correlati ┆ stributio ┆ tributio │
# │ str       ┆ ---       ┆ str       ┆ ---       ┆   ┆ ion…      ┆ on_…      ┆ n_R…      ┆ n_Mean…  │
# │           ┆ str       ┆           ┆ i64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ be1d79751 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ -0.244568 ┆ -0.175755 ┆ -0.510789 ┆ -0.14981 │
# │ 3962cc531 ┆ 5761-001- ┆           ┆           ┆   ┆           ┆           ┆           ┆ 8        │
# │ 38bf40c17 ┆ 01-1      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ bfd…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ c5e19078f ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ 0.584218  ┆ 0.122659  ┆ 0.298723  ┆ -0.29550 │
# │ 768719a36 ┆ 5761-001- ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ c7233564d ┆ 01-1      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ efa…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ bb62f3e78 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ 0.000598  ┆ 0.133839  ┆ -0.186927 ┆ -0.21589 │
# │ 34491d8e9 ┆ 5761-001- ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2bd12706d ┆ 01-1      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 756…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 969d9a333 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ -0.254597 ┆ 0.623077  ┆ -0.485477 ┆ -0.17874 │
# │ 283209ca2 ┆ 5761-001- ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 5162bd780 ┆ 01-1      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 80c…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 399590b2e ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ -0.079721 ┆ 0.087565  ┆ -0.350473 ┆ 0.444416 │
# │ d040a3193 ┆ 5761-001- ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ dbffd2d97 ┆ 01-1      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 673…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Identify plates that contains U2OS and A549 cells

# %%
# Split the dataset by cell type and treatment duration
# Filter U2OS cells (all records)
cpjump1_u2os_exp_metadata = cpjump1_experimental_data.filter(
    pl.col("Cell_type") == "U2OS"
)

# Filter A549 cells with density of 100 for consistency
cpjump1_a549_exp_metadata = cpjump1_experimental_data.filter(
    (pl.col("Cell_type") == "A549") & (pl.col("Density") == 100)
)

# Extract plate identifiers for each cell type
u2os_plates = cpjump1_u2os_exp_metadata["Assay_Plate_Barcode"].unique().to_list()
a549_plates = cpjump1_a549_exp_metadata["Assay_Plate_Barcode"].unique().to_list()

# Display the extracted plates for verification
print(f"U2OS plates: {u2os_plates}")
print(f"A549 plates: {a549_plates}")
# Out:
# U2OS plates: ['BR00117013', 'BR00117010', 'BR00117011', 'BR00117012']
# A549 plates: ['BR00117019', 'BR00117015', 'BR00117017', 'BR00117016']

# %% [markdown]
# Add the MoA data into the profiles

# %%
# merge moa data (join on Metadata_pert_iname)
cpjump1_df = cpjump1_df.filter(pl.col("Metadata_Plate").is_in(u2os_plates))
cpjump1_df = cpjump1_df.join(cpjump1_moa_df, how="inner", on="Metadata_pert_iname")

# Join cluster labels on Metadata_cell_id
cpjump1_df = cpjump1_df.join(
    cluster_labels_df,
    on="Metadata_cell_id",
    how="inner",  # Use inner join to keep only cells with cluster assignments
)
print(f"After joining cluster labels: {cpjump1_df.height} rows")

# Verify all required columns exist
required_cols = [
    "Metadata_cluster_id",
    "Metadata_cluster_ratio",
    "Metadata_control_type",
    "Metadata_pert_iname",
    "Metadata_moa",
]
missing_cols = [col for col in required_cols if col not in cpjump1_df.columns]
if missing_cols:
    raise ValueError(f"Missing required columns: {missing_cols}")

# print dataframe information
# displaying dataframe information
print("CPJUMP1 U2OS dataset")
print(f"Dataframe shape: {cpjump1_df.shape}")
print(
    "Number of poscon_cp",
    cpjump1_df.filter(pl.col("Metadata_control_type") == "poscon_cp")[
        "Metadata_pert_iname"
    ].n_unique(),
)
print(
    "Number of unique treatments that are not controls",
    cpjump1_df.filter(pl.col("Metadata_pert_type") == "trt")
    .select("Metadata_pert_iname")
    .n_unique(),
)

cpjump1_df.head()
# Out:
# After joining cluster labels: 1135692 rows
# CPJUMP1 U2OS dataset
# Dataframe shape: (1135692, 332)
# Number of poscon_cp 26
# Number of unique treatments that are not controls 256
# shape: (5, 332)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ … ┆ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ Metadata │
# │ cell_id   ┆ broad_sam ┆ solvent   ┆ ImageNumb ┆   ┆ cluster_i ┆ cluster_n ┆ treatment ┆ _cluster │
# │ ---       ┆ ple       ┆ ---       ┆ er        ┆   ┆ d         ┆ _cells    ┆ _n_cells  ┆ _ratio   │
# │ str       ┆ ---       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ str       ┆           ┆ i64       ┆   ┆ cat       ┆ u32       ┆ u32       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ be1d79751 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ gabapenti ┆ 2748      ┆ 2857      ┆ 0.961848 │
# │ 3962cc531 ┆ 5761-001- ┆           ┆           ┆   ┆ n-enacarb ┆           ┆           ┆          │
# │ 38bf40c17 ┆ 01-1      ┆           ┆           ┆   ┆ il_leiden ┆           ┆           ┆          │
# │ bfd…      ┆           ┆           ┆           ┆   ┆ _0        ┆           ┆           ┆          │
# │ c5e19078f ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ gabapenti ┆ 2748      ┆ 2857      ┆ 0.961848 │
# │ 768719a36 ┆ 5761-001- ┆           ┆           ┆   ┆ n-enacarb ┆           ┆           ┆          │
# │ c7233564d ┆ 01-1      ┆           ┆           ┆   ┆ il_leiden ┆           ┆           ┆          │
# │ efa…      ┆           ┆           ┆           ┆   ┆ _0        ┆           ┆           ┆          │
# │ bb62f3e78 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ gabapenti ┆ 2748      ┆ 2857      ┆ 0.961848 │
# │ 34491d8e9 ┆ 5761-001- ┆           ┆           ┆   ┆ n-enacarb ┆           ┆           ┆          │
# │ 2bd12706d ┆ 01-1      ┆           ┆           ┆   ┆ il_leiden ┆           ┆           ┆          │
# │ 756…      ┆           ┆           ┆           ┆   ┆ _0        ┆           ┆           ┆          │
# │ 969d9a333 ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ gabapenti ┆ 2748      ┆ 2857      ┆ 0.961848 │
# │ 283209ca2 ┆ 5761-001- ┆           ┆           ┆   ┆ n-enacarb ┆           ┆           ┆          │
# │ 5162bd780 ┆ 01-1      ┆           ┆           ┆   ┆ il_leiden ┆           ┆           ┆          │
# │ 80c…      ┆           ┆           ┆           ┆   ┆ _0        ┆           ┆           ┆          │
# │ 399590b2e ┆ BRD-A8666 ┆ DMSO      ┆ 1         ┆ … ┆ gabapenti ┆ 2748      ┆ 2857      ┆ 0.961848 │
# │ d040a3193 ┆ 5761-001- ┆           ┆           ┆   ┆ n-enacarb ┆           ┆           ┆          │
# │ dbffd2d97 ┆ 01-1      ┆           ┆           ┆   ┆ il_leiden ┆           ┆           ┆          │
# │ 673…      ┆           ┆           ┆           ┆   ┆ _0        ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Generate a shuffled baseline dataset

# %%
# create a subsetted dataframe for faster testing (optional)
# subset around 10%
# ----------------------------------------------------------------
# comment below lines to disable subsetting
# subset = 0.10
# print("Subsetting data for testing purposes...")
# print("subsetting fraction:", subset)
# print("original dataframe shape:", cpjump1_df.shape)
# cpjump1_df = (
#     cpjump1_df.group_by(["Metadata_Plate", "Metadata_Well"])
#     .agg(pl.all().sample(fraction=subset, seed=0))
#     .explode(pl.all().exclude(["Metadata_Plate", "Metadata_Well"]))
# )
# print(f"New dataframe shape: {cpjump1_df.shape}")
# ----------------------------------------------------------------

# Create the shuffled baseline dataset
cpjump1_df_shuffled = shuffle_feature_profiles(cpjump1_df, shared_features, seed=42)
# Out:
# Subsetting data for testing purposes...
# subsetting fraction: 0.1
# original dataframe shape: (1135692, 332)
# New dataframe shape: (112862, 332)

# %%
# Parameters
# negcon_sub_sample (int) - fraction of negative controls to sub-sample
# n_same_moa_treatments (int) - minimum number of treatments sharing the same MoA
negcon_sub_sample = 0.25
n_same_moa_treatments = 3
n_iterations = 5

# %%
# counts number of treatments that have the same MoA
moa_counts = (
    (
        cpjump1_df.group_by("Metadata_moa").agg(
            pl.col("Metadata_pert_iname").n_unique().alias("treatment_count")
        )
    )
    .sort("treatment_count", descending=True)
    .filter(pl.col("treatment_count") >= n_same_moa_treatments)
)

# get all treatments with MoAs that have that passes the threshold of n_same_moa_treatments
selected_treatments_df = (
    cpjump1_df.filter(
        pl.col("Metadata_moa").is_in(moa_counts["Metadata_moa"].implode())
    )
    .select("Metadata_pert_iname")
    .unique()
    .to_series()
    .to_list()
) + ["DMSO"]

# display results
pprint(
    f"Number of MoAs with at least {n_same_moa_treatments} treatments: {moa_counts.height}"
)
pprint(f"The treatments are: {selected_treatments_df}")
print(
    f"total amount of treatments to be analyzed: {moa_counts['treatment_count'].sum()}"
)
moa_counts
# Out:
# 'Number of MoAs with at least 3 treatments: 19'
# ("The treatments are: ['romidepsin', 'CYM-50260', 'efaroxan', 'glutamine-(l)', "
#  "'SRC-kinase-inhibitor-I', 'dalfampridine', '4-CMTB', 'picrotin', 'NBQX', "
#  "'sodium-butyrate', 'EI1', 'PF-06463922', 'trometamol', 'PP-2', 'bufexamac', "
#  "'niflumic-acid', 'Ro-20-1724', '1-octanol', 'terazosin', 'sulfasalazine', "
#  "'bepridil', 'puromycin', 'droxinostat', 'zaprinast', 'NSC-663284', "
#  "'amlodipine', 'PHA-793887', 'arcyriaflavin-a', 'L-Cystine', 'cycloheximide', "
#  "'RX-821002', 'KH-CB19', 'RGB-286638', 'CYM-5520', 'ceritinib', 'TCN201', "
#  "'nimodipine', 'NSC-625987', 'BRL-50481', 'nilvadipine', 'quinidine', "
#  "'picrotoxinin', 'ganetespib', 'guanidine', 'PP-1', 'UNC1999', 'triamterene', "
#  "'homoharringtonine', 'ibutilide', 'CYM-5442', 'diltiazem', 'amiloride', "
#  "'lercanidipine', 'NVP-HSP990', 'cilostazol', 'saclofen', 'VU591', "
#  "'purvalanol-a', 'GSK-37647', 'RGFP966', 'benzamil', 'ozanimod', "
#  "'salicylic-acid', 'carzenide', 'SB-505124', 'felodipine', 'pidolic-acid', "
#  "'flupirtine', 'WH-4-023', 'ryuvidine', 'geldanamycin', 'NSC-95397', "
#  "'TUG-891', 'DMSO']")
# total amount of treatments to be analyzed: 73
# shape: (19, 2)
# ┌─────────────────────────────────┬─────────────────┐
# │ Metadata_moa                    ┆ treatment_count │
# │ ---                             ┆ ---             │
# │ str                             ┆ u32             │
# ╞═════════════════════════════════╪═════════════════╡
# │ calcium channel blocker         ┆ 7               │
# │ unknown                         ┆ 6               │
# │ CDK inhibitor                   ┆ 5               │
# │ sodium channel blocker          ┆ 4               │
# │ cyclooxygenase inhibitor        ┆ 4               │
# │ …                               ┆ …               │
# │ protein synthesis inhibitor     ┆ 3               │
# │ free fatty acid receptor agoni… ┆ 3               │
# │ adrenergic receptor antagonist  ┆ 3               │
# │ potassium channel blocker       ┆ 3               │
# │ ALK tyrosine kinase receptor i… ┆ 3               │
# └─────────────────────────────────┴─────────────────┘

# %%
# reduce the profiles to only the treatments with MoAs that have at least n_same_moa_treatments
cpjump1_df = cpjump1_df.filter(
    pl.col("Metadata_pert_iname").is_in(selected_treatments_df)
)

# displaying dataframe information
print("CPJUMP1 U2OS dataset after filtering treatments by MoA counts")
print("Dataframe shape: {cpjump1_df.shape}")
print(f"Numbero of treatment: {cpjump1_df['Metadata_pert_iname'].n_unique()}")
cpjump1_df.head()
# Out:
# CPJUMP1 U2OS dataset after filtering treatments by MoA counts
# Dataframe shape: {cpjump1_df.shape}
# Numbero of treatment: 74
# shape: (5, 332)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ … ┆ Metadata_ ┆ Metadata_ ┆ Metadata_ ┆ Metadata │
# │ Plate     ┆ Well      ┆ cell_id   ┆ broad_sam ┆   ┆ cluster_i ┆ cluster_n ┆ treatment ┆ _cluster │
# │ ---       ┆ ---       ┆ ---       ┆ ple       ┆   ┆ d         ┆ _cells    ┆ _n_cells  ┆ _ratio   │
# │ str       ┆ str       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆ str       ┆   ┆ cat       ┆ u32       ┆ u32       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ BR0011701 ┆ F06       ┆ 6c4800fc3 ┆ DMSO      ┆ … ┆ DMSO_leid ┆ 225142    ┆ 234693    ┆ 0.959304 │
# │ 1         ┆           ┆ 7fd871ab4 ┆           ┆   ┆ en_0      ┆           ┆           ┆          │
# │           ┆           ┆ bb8816739 ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 3b0…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ BR0011701 ┆ F06       ┆ 4f02de5a1 ┆ DMSO      ┆ … ┆ DMSO_leid ┆ 225142    ┆ 234693    ┆ 0.959304 │
# │ 1         ┆           ┆ c1b35bfde ┆           ┆   ┆ en_0      ┆           ┆           ┆          │
# │           ┆           ┆ 81bff5edd ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 5d4…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ BR0011701 ┆ F06       ┆ 736ffee60 ┆ DMSO      ┆ … ┆ DMSO_leid ┆ 225142    ┆ 234693    ┆ 0.959304 │
# │ 1         ┆           ┆ a795514b8 ┆           ┆   ┆ en_0      ┆           ┆           ┆          │
# │           ┆           ┆ 8b65050b1 ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ db9…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ BR0011701 ┆ F06       ┆ 0c573a850 ┆ DMSO      ┆ … ┆ DMSO_leid ┆ 225142    ┆ 234693    ┆ 0.959304 │
# │ 1         ┆           ┆ 843ec4153 ┆           ┆   ┆ en_0      ┆           ┆           ┆          │
# │           ┆           ┆ e8bf869c5 ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ e0b…      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ BR0011701 ┆ F06       ┆ b22b7f40a ┆ DMSO      ┆ … ┆ DMSO_leid ┆ 225142    ┆ 234693    ┆ 0.959304 │
# │ 1         ┆           ┆ 1d453c009 ┆           ┆   ┆ en_0      ┆           ┆           ┆          │
# │           ┆           ┆ 0cc71eccc ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 2a9…      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# make an MoA look up dictionary {"treatment_name": "MoA"}
moa_lookup = dict(
    zip(cpjump1_moa_df["Metadata_pert_iname"], cpjump1_moa_df["Metadata_moa"])
)
pprint(moa_lookup)
# Out:
# {'1-EBIO': 'potassium channel activator',
#  '1-octanol': 'unknown',
#  '2,5-furandimethanol': 'hemoglobin modulator',
#  '2-Oleoylglycerol': 'glucose dependent insulinotropic receptor ligand',
#  '4-CMTB': 'free fatty acid receptor agonist',
#  '4-methylhistamine': 'histamine receptor agonist',
#  '7-hydroxystaurosporine': 'CDK inhibitor|CHK inhibitor|PKC inhibitor',
#  'A-987306': 'histamine receptor antagonist',
#  'A205804': 'ICAM1 expression inhibitor',
#  'AC-710': 'PDGFR tyrosine kinase receptor inhibitor',
#  'AK-7': 'SIRT inhibitor',
#  'AMG900': 'Aurora kinase inhibitor',
#  'ANR-94': 'A1 adenosine receptor antagonist',
#  'AR-12': 'phosphoinositide dependent kinase inhibitor',
#  'AVL-292': "Bruton's tyrosine kinase (BTK) inhibitor",
#  'AZ191': 'DYRK inhibitor',
#  'AZD1283': 'purinergic receptor antagonist',
#  'AZD7762': 'CHK inhibitor',
#  'AZD9668': 'elastase inhibitor',
#  'BAM7': 'BAX activator',
#  'BAN-ORL-24': 'nociceptin/orphanin FQ receptor antagonist',
#  'BAX-channel-blocker': 'cytochrome C release inhibitor',
#  'BAY-87-2243': 'hypoxia inducible factor inhibitor',
#  'BI-2536': 'PLK inhibitor',
#  'BMS-536924': 'IGF-1 inhibitor',
#  'BMS-587101': 'integrin antagonist',
#  'BQ-788': 'endothelin receptor antagonist',
#  'BRL-50481': 'phosphodiesterase inhibitor',
#  'BVT-948': 'tyrosine phosphatase inhibitor',
#  'CC-401': 'JNK inhibitor',
#  'CCG-50014': 'G protein signaling inhibitor',
#  'CCG-63802': 'G protein signaling inhibitor',
#  'CGP-53353': 'EGFR inhibitor|PKC inhibitor',
#  'CP-724714': 'EGFR inhibitor|protein tyrosine kinase inhibitor',
#  'CVT-10216': 'aldehyde dehydrogenase inhibitor',
#  'CYM-50260': 'sphingosine 1 phosphate receptor agonist',
#  'CYM-50358': 'sphingosine 1-phosphate receptor antagonist',
#  'CYM-5442': 'sphingosine 1 phosphate receptor agonist',
#  'CYM-5520': 'sphingosine 1 phosphate receptor agonist',
#  'CYT-997': 'tubulin polymerization inhibitor',
#  'DDR1-IN-1': 'discoidin domain receptor inhibitor',
#  'DG-172': 'PPAR receptor inverse agonist',
#  'DMSO': 'control vehicle',
#  'EI1': 'histone lysine methyltransferase inhibitor',
#  'FERb-033': 'EGFR inhibitor',
#  'FK-866': 'niacinamide phosphoribosyltransferase inhibitor',
#  'FPS-ZM1': 'RAGE receptor antagonist',
#  'GK921': 'transglutaminase inhibitor',
#  'GNF-5': 'Bcr-Abl kinase inhibitor',
#  'GNF-5837': 'growth factor receptor inhibitor',
#  'GSK-37647': 'free fatty acid receptor agonist',
#  'GSK1070916': 'Aurora kinase inhibitor',
#  'GSK2110183': 'AKT inhibitor',
#  'GSK3787': 'PPAR receptor antagonist',
#  'GW-311616': 'leukocyte elastase inhibitor|elastase inhibitor',
#  'H2L-5765834': 'lysophosphatidic acid receptor antagonist',
#  'IRL-2500': 'endothelin receptor antagonist',
#  'IWP-L6': 'porcupine inhibitor',
#  'JTE-013': 'lysophospholipid receptor antagonist',
#  'JTE-607': 'cytokine production inhibitor',
#  'KG-5': 'RAF inhibitor',
#  'KH-CB19': 'CDC inhibitor',
#  'KI-16425': 'lysophosphatidic acid receptor antagonist',
#  'KU-55933': 'ATM kinase inhibitor',
#  'KU-60019': 'ATM kinase inhibitor',
#  'L-Cystine': 'unknown',
#  'L-proline': 'glutamate receptor agonist',
#  'LDN-212854': 'bone morphogenic protein inhibitor',
#  'LDN-27219': 'tissue transglutaminase inhibitor',
#  'LGK-974': 'porcupine inhibitor',
#  'LOXO-101': 'tropomyosin receptor kinase inhibitor',
#  'LY2109761': 'TGF beta receptor inhibitor',
#  'M-25': 'smoothened receptor antagonist',
#  'MCOPPB': 'nociceptin/orphanin FQ (NOP) receptor agonist',
#  'ME-0328': 'PPAR receptor antagonist',
#  'ML-193': 'G protein-coupled receptor antagonist',
#  'ML-228': 'hypoxia inducible factor activator',
#  'ML-323': 'ubiquitin specific protease inhibitor',
#  'N-alpha-Methylhistamine-dihydrochloride': 'histamine receptor agonist',
#  'N6-cyclopentyladenosine': 'adenosine receptor agonist',
#  'NBQX': 'glutamate receptor antagonist',
#  'NNC-55-0396': 'T-type calcium channel blocker',
#  'NQDI-1': 'caspase inhibitor',
#  'NS-11021': 'calcium-activated potassium channel activator',
#  'NS-309': 'calcium-activated potassium channel activator',
#  'NSC-625987': 'CDK inhibitor',
#  'NSC-632839': 'ubiquitin specific protease inhibitor',
#  'NSC-663284': 'CDC inhibitor',
#  'NSC-95397': 'CDC inhibitor',
#  'NVP-ADW742': 'insulin growth factor receptor inhibitor',
#  'NVP-AEW541': 'IGF-1 inhibitor',
#  'NVP-HSP990': 'HSP inhibitor',
#  'NVS-PAK1-1': 'p21 activated kinase inhibitor',
#  'OMDM-2': 'FAAH inhibitor',
#  'PD-98059': 'MEK inhibitor',
#  'PETCM': 'caspase activator',
#  'PF-03758309': 'p21 activated kinase inhibitor',
#  'PF-04217903': 'c-Met inhibitor',
#  'PF-05190457': 'growth hormone secretagogue receptor inverse agonist',
#  'PF-06463922': 'ALK tyrosine kinase receptor inhibitor',
#  'PF-431396': 'focal adhesion kinase inhibitor',
#  'PF-915275': '11-beta hydroxysteroid dehydrogenase inhibitor',
#  'PFI-1': 'bromodomain inhibitor',
#  'PHA-793887': 'CDK inhibitor',
#  'PP-1': 'src inhibitor',
#  'PP-121': 'protein tyrosine kinase inhibitor',
#  'PP-2': 'src inhibitor',
#  'RGB-286638': 'CDK inhibitor',
#  'RGFP966': 'HDAC inhibitor',
#  'RKI-1447': 'rho associated kinase inhibitor',
#  'RX-821002': 'adrenergic receptor antagonist',
#  'Ro-1138452': 'prostanoid receptor antagonist',
#  'Ro-20-1724': 'phosphodiesterase inhibitor',
#  'SB-202190': 'p38 MAPK inhibitor',
#  'SB-203580': 'p38 MAPK inhibitor',
#  'SB-505124': 'ALK tyrosine kinase receptor inhibitor',
#  'SGX523': 'hepatocyte growth factor receptor inhibitor',
#  'SKLB1002': 'VEGFR inhibitor',
#  'SRC-kinase-inhibitor-I': 'src inhibitor',
#  'SU3327': 'JNK inhibitor',
#  'SirReal-2': 'SIRT inhibitor',
#  'TC-S-7004': 'DYRK inhibitor',
#  'TCN201': 'glutamate receptor antagonist',
#  'TFC-007': 'prostaglandin inhibitor',
#  'TG-003': 'CLK inhibitor',
#  'TG-02': 'CDK inhibitor|FLT3 inhibitor|JAK inhibitor',
#  'TG-101348': 'FLT3 inhibitor|JAK inhibitor',
#  'TUG-891': 'free fatty acid receptor agonist',
#  'U-0521': 'catechol O methyltransferase inhibitor',
#  'UNC1999': 'histone lysine methyltransferase inhibitor',
#  'UNC2025': 'MER tyrosine kinase inhibitor|FLT3 inhibitor',
#  'VU591': 'potassium channel blocker',
#  'WH-4-023': 'src inhibitor',
#  'YC-1': 'guanylyl cyclase activator',
#  'ZK-93423': 'benzodiazepine receptor agonist',
#  'ZK811752': 'CC chemokine receptor antagonist',
#  'ZM-336372': 'RAF inhibitor',
#  'acalabrutinib': "Bruton's tyrosine kinase (BTK) inhibitor",
#  'acetohexamide': 'ATP channel blocker',
#  'acetylcysteine': 'mucolytic agent',
#  'afimoxifene': 'estrogen receptor antagonist',
#  'alda-1': 'aldehyde dehydrogenase activator',
#  'aloxistatin': 'protease inhibitor',
#  'alrestatin': 'aldose reductase inhibitor',
#  'amiloride': 'sodium channel blocker',
#  'aminopurvalanol-a': 'CDK inhibitor|tyrosine kinase inhibitor',
#  'amlexanox': 'histamine receptor modulator',
#  'amlodipine': 'calcium channel blocker',
#  'anandamide': 'cannabinoid receptor agonist',
#  'anisomycin': 'DNA synthesis inhibitor',
#  'apatinib': 'RET tyrosine kinase inhibitor',
#  'arcyriaflavin-a': 'CDK inhibitor',
#  'aripiprazole': 'serotonin receptor agonist|serotonin receptor antagonist',
#  'arundic-acid': 'astrocyte modulating agent',
#  'ascorbic-acid': 'antioxidant',
#  'azacitidine': 'DNA methyltransferase inhibitor',
#  'azathioprine': 'dehydrogenase inhibitor',
#  'azeliragon': 'RAGE receptor antagonist',
#  'baclofen': 'benzodiazepine receptor agonist',
#  'batimastat': 'matrix metalloprotease inhibitor',
#  'benzamil': 'sodium channel blocker',
#  'bepridil': 'calcium channel blocker',
#  'briciclib': 'cyclin D inhibitor',
#  'brinzolamide': 'carbonic anhydrase inhibitor',
#  'bufexamac': 'cyclooxygenase inhibitor',
#  'buparlisib': 'PI3K inhibitor',
#  'carzenide': 'unknown',
#  'castanospermine': 'glucosidase inhibitor',
#  'cediranib': 'KIT inhibitor|VEGFR inhibitor',
#  'ceritinib': 'ALK tyrosine kinase receptor inhibitor',
#  'cetilistat': 'triacylglycerol lipase inhibitor',
#  'cilostazol': 'phosphodiesterase inhibitor',
#  'citric-acid': 'coagulation factor inhibitor',
#  'colchicine': 'microtubule inhibitor',
#  'conivaptan': 'vasopressin receptor antagonist',
#  'coumarin': 'vitamin K antagonist',
#  'cycloheximide': 'protein synthesis inhibitor',
#  'cyclophosphamide': 'DNA alkylating agent',
#  'cyclosporine': 'calcineurin inhibitor',
#  'dalbavancin': 'bacterial cell wall synthesis inhibitor',
#  'dalfampridine': 'potassium channel blocker',
#  'danusertib': 'Aurora kinase inhibitor|growth factor receptor inhibitor',
#  'deferasirox': 'chelating agent',
#  'delanzomib': 'proteasome inhibitor',
#  'desonide': 'glucocorticoid receptor agonist',
#  'dexamethasone': 'glucocorticoid receptor agonist',
#  'diacerein': 'interleukin inhibitor',
#  'dilazep': 'adenosine reuptake inhibitor',
#  'diltiazem': 'calcium channel blocker',
#  'dinoprostone': 'prostanoid receptor agonist',
#  'droxinostat': 'HDAC inhibitor',
#  'dyphylline': 'adenosine receptor antagonist|phosphodiesterase inhibitor',
#  'edoxaban': 'coagulation factor inhibitor',
#  'efaproxiral': 'haemoglobin oxygen release stimulant',
#  'efaroxan': 'adrenergic receptor antagonist',
#  'enflurane': 'membrane permeability inhibitor',
#  'enilconazole': 'sterol demethylase inhibitor',
#  'epoprostenol': 'prostacyclin analog',
#  'epothilone-b': 'microtubule stabilizing agent|tubulin polymerization '
#                  'inhibitor',
#  'ethoxzolamide': 'carbonic anhydrase inhibitor',
#  'ethyl-pyruvate': 'tumor necrosis factor production inhibitor',
#  'felodipine': 'calcium channel blocker',
#  'filgotinib': 'JAK inhibitor',
#  'flindokalner': 'potassium channel agonist',
#  'fludarabine': 'ribonucleotide reductase inhibitor',
#  'fludarabine-phosphate': 'ribonucleotide reductase inhibitor',
#  'flufenamic-acid': 'chloride channel blocker',
#  'flupirtine': 'glutamate receptor antagonist',
#  'fomepizole': 'alcohol dehydrogenase inhibitor',
#  'formononetin': 'alcohol dehydrogenase inhibitor',
#  'gabapentin-enacarbil': 'adrenergic receptor agonist',
#  'ganetespib': 'HSP inhibitor',
#  'geldanamycin': 'HSP inhibitor',
#  'glutamine-(l)': 'unknown',
#  'glyburide': 'ATP channel blocker|insulin secretagogue|sulfonylurea',
#  'guanidine': 'HSP inhibitor',
#  'halopemide': 'phospholipase inhibitor',
#  'hexestrol': 'synthetic estrogen',
#  'homoharringtonine': 'protein synthesis inhibitor',
#  'ibudilast': 'leukotriene receptor antagonist|phosphodiesterase inhibitor',
#  'ibutamoren': 'growth hormone secretagogue receptor agonist',
#  'ibutilide': 'potassium channel blocker',
#  'ilomastat': 'matrix metalloprotease inhibitor',
#  'ingenol-mebutate': 'PKC activator',
#  'isoflurane': 'inhaled anaesthetic',
#  'ixabepilone': 'microtubule stabilizing agent',
#  'leflunomide': 'dihydroorotate dehydrogenase inhibitor|PDGFR tyrosine kinase '
#                 'receptor inhibitor',
#  'lercanidipine': 'calcium channel blocker',
#  'lonafarnib': 'farnesyltransferase inhibitor',
#  'loperamide': 'opioid receptor agonist',
#  'meclofenamic-acid': 'cyclooxygenase inhibitor|prostanoid receptor antagonist',
#  'menadione': 'mitochondrial DNA polymerase inhibitor|phosphatase inhibitor',
#  'methoxsalen': 'DNA synthesis inhibitor',
#  'miconazole': 'bacterial cell wall synthesis inhibitor',
#  'miglitol': 'glucosidase inhibitor',
#  'minocycline': 'bacterial 30S ribosomal subunit inhibitor',
#  'misoprostol': 'prostanoid receptor agonist',
#  'motesanib': 'KIT inhibitor|PDGFR tyrosine kinase receptor inhibitor|VEGFR '
#               'inhibitor',
#  'nafamostat': 'serine protease inhibitor',
#  'nalmefene': 'opioid receptor antagonist',
#  'nevirapine': 'non-nucleoside reverse transcriptase inhibitor',
#  'nialamide': 'monoamine oxidase inhibitor',
#  'nicotine': 'acetylcholine receptor agonist',
#  'niflumic-acid': 'cyclooxygenase inhibitor',
#  'nilvadipine': 'calcium channel blocker',
#  'nimodipine': 'calcium channel blocker',
#  'octreotide': 'somatostatin receptor agonist',
#  'olanzapine': 'dopamine receptor antagonist|serotonin receptor antagonist',
#  'olopatadine': 'histamine receptor antagonist',
#  'orantinib': 'FGFR inhibitor|PDGFR tyrosine kinase receptor inhibitor|VEGFR '
#               'inhibitor',
#  'oxibendazole': 'tubulin polymerization inhibitor',
#  'oxytocin': 'oxytocin receptor agonist',
#  'ozagrel': 'thromboxane synthase inhibitor',
#  'ozanimod': 'sphingosine 1 phosphate receptor agonist',
#  'paliperidone': 'dopamine receptor antagonist|serotonin receptor antagonist',
#  'pazopanib': 'KIT inhibitor|PDGFR tyrosine kinase receptor inhibitor|VEGFR '
#               'inhibitor',
#  'pentostatin': 'adenosine deaminase inhibitor|ribonucleotide reductase '
#                 'inhibitor',
#  'phenolphthalein': 'indicator dye',
#  'phenylbutazone': 'cyclooxygenase inhibitor|prostanoid receptor antagonist',
#  'picrotin': 'GABA receptor antagonist',
#  'picrotoxinin': 'GABA receptor antagonist',
#  'pidolic-acid': 'unknown',
#  'polydatin': 'ICAM1 expression inhibitor',
#  'ponatinib': 'Bcr-Abl kinase inhibitor|FLT3 inhibitor|PDGFR tyrosine kinase '
#               'receptor inhibitor',
#  'prasugrel': 'purinergic receptor antagonist',
#  'procaine': 'HMGCR inhibitor',
#  'puromycin': 'protein synthesis inhibitor',
#  'purvalanol-a': 'CDK inhibitor',
#  'pyrrolidine-dithiocarbamate': 'NFkB pathway inhibitor',
#  'quinidine': 'sodium channel blocker',
#  'quinine': 'hemozoin biocrystallization inhibitor',
#  'racecadotril': 'enkephalinase inhibitor',
#  'regorafenib': 'FGFR inhibitor|KIT inhibitor|PDGFR tyrosine kinase receptor '
#                 'inhibitor|RAF inhibitor|RET tyrosine kinase inhibitor|VEGFR '
#                 'inhibitor',
#  'rifamycin': 'DNA directed RNA polymerase inhibitor',
#  'riociguat': 'guanylate cyclase stimulant',
#  'romidepsin': 'HDAC inhibitor',
#  'ruxolitinib': 'JAK inhibitor',
#  'ryuvidine': 'histone lysine methyltransferase inhibitor',
#  'saclofen': 'GABA receptor antagonist',
#  'sacubitril': 'neprilysin inhibitor',
#  'salicylic-acid': 'cyclooxygenase inhibitor',
#  'simvastatin': 'HMGCR inhibitor',
#  'sodium-butyrate': 'HDAC inhibitor',
#  'somatostatin': 'somatostatin receptor agonist',
#  'sorbinil': 'aldose reductase inhibitor',
#  'sotrastaurin': 'PKC inhibitor',
#  'spiroxatrine': 'serotonin receptor antagonist',
#  'sulfasalazine': 'cyclooxygenase inhibitor',
#  'sulfinpyrazone': 'uricosuric blocker',
#  'taladegib': 'smoothened receptor antagonist',
#  'terazosin': 'adrenergic receptor antagonist',
#  'thioguanine': 'purine antagonist',
#  'thiostrepton': 'FOXM1 inhibitor|protein synthesis inhibitor',
#  'torcitabine': 'DNA polymerase inhibitor',
#  'tranilast': 'angiogenesis inhibitor',
#  'trazodone': 'adrenergic receptor antagonist|serotonin receptor '
#               'antagonist|serotonin reuptake inhibitor',
#  'triamterene': 'sodium channel blocker',
#  'trihexyphenidyl': 'acetylcholine receptor antagonist',
#  'trometamol': 'unknown',
#  'vitamin-E': 'PKC inhibitor|LDL oxidation inhibitor',
#  'xanomeline': 'acetylcholine receptor agonist',
#  'zamifenacin': 'acetylcholine receptor antagonist',
#  'zaprinast': 'phosphodiesterase inhibitor'}

# %%
# Set up a logger to track the process below
logger = logging.getLogger("buscar_moa_analysis")
logger.setLevel(logging.INFO)

# Create file handler which logs even debug messages
log_file_path = moa_analysis_output_dir / "buscar_moa_analysis.log"
fh = logging.FileHandler(log_file_path)
fh.setLevel(logging.INFO)

# Create formatter and add it to the handlers
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
fh.setFormatter(formatter)

# Add the handlers to the logger
if not logger.hasHandlers():
    logger.addHandler(fh)
else:
    # Avoid duplicate handlers in Jupyter
    logger.handlers.clear()
    logger.addHandler(fh)

logger.info("Logger initialized for Buscar MoA analysis.")

# %%
# Run Buscar analysis for each treatment in both original and shuffled datasets
scores = {
    "original": {},
    "shuffled": {},
}  # store results here with dataset_type as top-level key
for dataset_type, cpjump1_df_to_use in {
    "original": cpjump1_df,
    "shuffled": cpjump1_df_shuffled,
}.items():
    logger.info(f"Starting analysis for dataset: {dataset_type}")
    for treatment in (
        pbar := tqdm(selected_treatments_df, desc=f"{dataset_type} treatments")
    ):
        # skip DMSO treatment
        if treatment == "DMSO":
            continue

        # getting current iteration for progress tracking
        current_iter = pbar.n
        logger.info(
            f"Processing treatment: {treatment} in dataset: {dataset_type}. Progress: {current_iter + 1}/{len(selected_treatments_df)}"
        )

        for n_iter in range(n_iterations):
            logger.info(
                f"Iteration {n_iter} for treatment: {treatment} in dataset: {dataset_type}"
            )

            # Sample from negative controls
            negcon_df = cpjump1_df_to_use.filter(
                pl.col("Metadata_control_type") == "negcon"
            ).sample(fraction=0.025, seed=n_iter)

            # Make the selected treatment as the positive control
            poscon_df = cpjump1_df_to_use.filter(
                pl.col("Metadata_pert_iname") == treatment
            )

            # check the shape of negcon_df and poscon_df if 0 raise an error
            if negcon_df.height == 0 or poscon_df.height == 0:
                logger.error(
                    f"Empty dataframe encountered for treatment {treatment} in dataset {dataset_type} at iteration {n_iter}. "
                    f"negcon_df height: {negcon_df.height}, poscon_df height: {poscon_df.height}. Skipping iteration."
                )
                raise ValueError("Empty dataframe encountered.")

            logger.debug(
                f"Dataset: {dataset_type} | Treatment: {treatment} | Iteration: {n_iter}"
            )

            # Buscar step 1: identify on and off signatures
            on_signatures, off_signatures, _ = get_signatures(
                ref_profiles=negcon_df,
                exp_profiles=poscon_df,
                morph_feats=shared_features,
                test_method="mann_whitney_u",
                p_threshold=0.05,
                seed=n_iter,
            )

            # Skip if no on or off signatures were found
            if len(on_signatures) == 0 and len(off_signatures) == 0:
                logger.warning(
                    f"No on or off signatures found for treatment {treatment}. Skipping."
                )
                logger.debug(f"on_signatures: {len(on_signatures)}")
                logger.debug(f"off_signatures: {len(off_signatures)}")
                continue

            # Buscar step 2: measure phenotypic activity and rank treatments (lower is better)
            logger.debug("measuring phenotypic activity...")
            treatment_phenotypic_dist_scores = measure_phenotypic_activity(
                profiles=pl.concat(
                    [
                        negcon_df,
                        cpjump1_df_to_use.filter(
                            pl.col("Metadata_pert_iname") != "DMSO"
                        ),
                    ]
                ),
                on_signature=on_signatures,
                off_signature=off_signatures,
                ref_treatment=treatment,
                cluster_col="Metadata_cluster_id",
                treatment_col="Metadata_pert_iname",
            )

            # Skip if no treatment rankings were generated
            if treatment_phenotypic_dist_scores.height == 0:
                logger.warning("No treatment scores calculated.. skipping")
                continue

            # Buscar step 3: rank treatments based on phenotypic distance scores
            logger.debug("Ranking treatments...")
            treatment_rankings = identify_compound_hit(
                distance_df=treatment_phenotypic_dist_scores, method="weighted_sum"
            )
            logger.debug(f"Ranking columns: {treatment_rankings.columns}")

            # Skip if no treatment rankings were generated
            if treatment_rankings.height == 0:
                logger.warning("No treatment rankings computed. Skipping iteration...")
                continue

            # Prepare results for this iteration
            logger.debug("storing results for this iteration...")
            result = {
                "compound_scores": dict(
                    zip(
                        treatment_rankings["treatment"],
                        treatment_rankings["compound_score"],
                    )
                ),
                "ranks": dict(
                    zip(treatment_rankings["treatment"], treatment_rankings["rank"])
                ),
                "moa": moa_lookup[treatment],
            }

            # Store per treatment and per iteration under dataset_type
            if treatment not in scores[dataset_type]:
                scores[dataset_type][treatment] = {}

            iteration_key = f"iteration_{n_iter}"
            scores[dataset_type][treatment][iteration_key] = result

            # Save after each iteration
            with open(
                (moa_analysis_output_dir / "cpjump1_buscar_scores.json").resolve(
                    strict=False
                ),
                "w",
            ) as f:
                json.dump(scores, f, indent=4, default=str)
            logger.info(
                f"Saved results for treatment: {treatment}, iteration: {n_iter}, dataset: {dataset_type}"
            )
# Out:
# shuffled treatments:  16%|█▌        | 12/74 [25:33<2:21:10, 136.62s/it]/home/erikserrano/Software/miniconda3/envs/buscar/lib/python3.12/site-packages/ot/lp/__init__.py:630: UserWarning: Problem infeasible. Check that a and b are in the simplex
#   check_result(result_code)
# shuffled treatments:  19%|█▉        | 14/74 [29:55<2:13:20, 133.34s/it]
